# %%
import pandas as pd

# %% [markdown]
# # analysis benchmark

# %%
df_benchmark = pd.read_csv('./files/email_benchmark1.csv', header=1, sep=', ' )
df_benchmark.head()
# Out:
# /tmp/ipykernel_24535/2091687483.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_benchmark = pd.read_csv('./files/email_benchmark1.csv', header=1, sep=', ' )
#                                                query  \
# 0            ferdinand punkt reicht at bla punkt com
# 1                  pedro punkt ebner at mail dot com
# 2  meine email ist m strich martha holz at bla pu...
# 3                          s punkt w at mercedes d e
# 4                 nele punkt gürtler at mail dot com
#
#                email_result                     email  issue
# 0  ferdinand.reicht@bla.com  ferdinand.reichl@bla.com  voice
# 1      pedro.ebner@mail.com     pietro.ebner@mail.com  voice
# 2      m-marthaholz@bla.com      n-mahrenholz@bla.com  voice
# ...

# %%
df_benchmark.groupby('issue').count()
# Out:
#            query  email_result  email
# issue
# luis          14            14     14
# validator     11            11     11
# voice        148           148    148

# %%
df_benchmark[df_benchmark.issue == 'validator']
# Out:
#                                                 query  \
# 11    steven andreas strich m dreizehn at bla dot com
# 15             das is t p neunzehn at gmail punkt com
# 16       s punkt bartel vierzehn at tonline punkt com
# 39                    die punkt p at mercedes dot com
# 44     das ist p punkt k fünfzig at hotmail punkt com
# 45        b strich lampi ne dreizehn at gmail dot com
# 50       s strich barenowska sechzehn at mercedes d e
# 66   helen stefanie minus r vierzehn at gmail dot com
# 92             u punkt wiedemann elf at gmx punkt com
# 96                j punkt w vierzehn at gmx punkt d e
# 153  g punkt neun juni neunzehn at mercedes punkt com
#
#                         email_result                        email      issue
# 11         andreas-mdreizehn@bla.com    stevenandreas-m13@bla.com  validator
# 15            istpneunzehn@gmail.com               ep19@gmail.com  validator
# 16      s.bartelvierzehn@tonline.com     s.barthel14@t-online.com  validator
# ...

# %%
df_benchmark[df_benchmark.issue == 'luis']
# Out:
#                                                  query  \
# 6    die adresse lautet mike hessam punkt s at tonl...
# 9                 andre nico punkt fink at gmx dot com
# 25              hans georg punkt z at mercedes dot com
# 27             meine email ist wie strich t at gmx d e
# 35          mark oliver punkt steyer at mail punkt com
# 36               silvia paula punkt s at gmx punkt d e
# 47             horst dieter punkt s at hotmail dot com
# 54   meine email ist james william punkt meister at...
# 55                      mark oliver punkt v at bla d e
# 74   die adresse lautet ernst august strich hertz a...
# 90         mike hessam punkt walbeck at test punkt com
# 98   meine email ist christian franz punkt kiefer a...
# 118          hans henning punkt ayten at gmail dot com
# 165  jörn hendrik minus schierling wanze at mail do...
#
#                      email_result                                   email  \
# ...

# %%
len([i for i in df_benchmark[df_benchmark.issue == 'voice'].email_result.apply(lambda x: x.split('@')[1]) if '.' not in i])
# Out:
# 70

# %%
[i for i in df_benchmark[df_benchmark.issue == 'voice'].email_result.apply(lambda x: x.split('@')[1]).unique() if '.' not in i]
# Out:
# ['mercedesde',
#  'gmailde',
#  'gmxde',
#  'tonlinede',
#  'testde',
#  'blade',
#  'hotmailde',
#  'mailde']

# %%
txt = """
    <tr><td>63</td><td><img src="/load_content.php?u=t-online.de" style="width:24px; height:24px;"></td><td>t-online.de</td><td>0.09% </td></tr>
    <tr><td>64</td><td><img src="/load_content.php?u=aliceadsl.fr" style="width:24px; height:24px;"></td><td>aliceadsl.fr</td><td>0.08% </td></tr>
    <tr><td>65</td><td><img src="/load_content.php?u=virgilio.it" style="width:24px; height:24px;"></td><td>virgilio.it</td><td>0.08% </td></tr>
    <tr><td>66</td><td><img src="/load_content.php?u=home.nl" style="width:24px; height:24px;"></td><td>home.nl</td><td>0.07% </td></tr>
    <tr><td>67</td><td><img src="/load_content.php?u=qq.com" style="width:24px; height:24px;"></td><td>qq.com</td><td>0.07% </td></tr>
    <tr><td>68</td><td><img src="/load_content.php?u=telenet.be" style="width:24px; height:24px;"></td><td>telenet.be</td><td>0.07% </td></tr>
    <tr><td>69</td><td><img src="/load_content.php?u=me.com" style="width:24px; height:24px;"></td><td>me.com</td><td>0.07% </td></tr>
    <tr><td>70</td><td><img src="/load_content.php?u=yahoo.com.ar" style="width:24px; height:24px;"></td><td>yahoo.com.ar</td><td>0.07% </td></tr>
    <tr><td>71</td><td><img src="/load_content.php?u=tiscali.co.uk" style="width:24px; height:24px;"></td><td>tiscali.co.uk</td><td>0.07% </td></tr>
    <tr><td>72</td><td><img src="/load_content.php?u=yahoo.com.mx" style="width:24px; height:24px;"></td><td>yahoo.com.mx</td><td>0.07% </td></tr>
    <tr><td>73</td><td><img src="/load_content.php?u=voila.fr" style="width:24px; height:24px;"></td><td>voila.fr</td><td>0.06% </td></tr>
    <tr><td>74</td><td><img src="/load_content.php?u=gmx.net" style="width:24px; height:24px;"></td><td>gmx.net</td><td>0.06% </td></tr>
    <tr><td>75</td><td><img src="/load_content.php?u=mail.com" style="width:24px; height:24px;"></td><td>mail.com</td><td>0.06% </td></tr>
    <tr><td>76</td><td><img src="/load_content.php?u=planet.nl" style="width:24px; height:24px;"></td><td>planet.nl</td><td>0.06% </td></tr>
    <tr><td>77</td><td><img src="/load_content.php?u=tin.it" style="width:24px; height:24px;"></td><td>tin.it</td><td>0.06% </td></tr>
    <tr><td>78</td><td><img src="/load_content.php?u=live.it" style="width:24px; height:24px;"></td><td>live.it</td><td>0.06% </td></tr>
    <tr><td>79</td><td><img src="/load_content.php?u=ntlworld.com" style="width:24px; height:24px;"></td><td>ntlworld.com</td><td>0.06% </td></tr>
    <tr><td>80</td><td><img src="/load_content.php?u=arcor.de" style="width:24px; height:24px;"></td><td>arcor.de</td><td>0.06% </td></tr>
    <tr><td>81</td><td><img src="/load_content.php?u=yahoo.co.id" style="width:24px; height:24px;"></td><td>yahoo.co.id</td><td>0.06% </td></tr>
    <tr><td>82</td><td><img src="/load_content.php?u=frontiernet.net" style="width:24px; height:24px;"></td><td>frontiernet.net</td><td>0.06% </td></tr>
    <tr><td>83</td><td><img src="/load_content.php?u=hetnet.nl" style="width:24px; height:24px;"></td><td>hetnet.nl</td><td>0.05% </td></tr>
    <tr><td>84</td><td><img src="/load_content.php?u=live.com.au" style="width:24px; height:24px;"></td><td>live.com.au</td><td>0.05% </td></tr>
    <tr><td>85</td><td><img src="/load_content.php?u=yahoo.com.sg" style="width:24px; height:24px;"></td><td>yahoo.com.sg</td><td>0.05% </td></tr>
    <tr><td>86</td><td><img src="/load_content.php?u=zonnet.nl" style="width:24px; height:24px;"></td><td>zonnet.nl</td><td>0.05% </td></tr>
    <tr><td>87</td><td><img src="/load_content.php?u=club-internet.fr" style="width:24px; height:24px;"></td><td>club-internet.fr</td><td>0.05% </td></tr>
    <tr><td>88</td><td><img src="/load_content.php?u=juno.com" style="width:24px; height:24px;"></td><td>juno.com</td><td>0.05% </td></tr>
    <tr><td>89</td><td><img src="/load_content.php?u=optusnet.com.au" style="width:24px; height:24px;"></td><td>optusnet.com.au</td><td>0.05% </td></tr>
    <tr><td>90</td><td><img src="/load_content.php?u=blueyonder.co.uk" style="width:24px; height:24px;"></td><td>blueyonder.co.uk</td><td>0.05% </td></tr>
    <tr><td>91</td><td><img src="/load_content.php?u=bluewin.ch" style="width:24px; height:24px;"></td><td>bluewin.ch</td><td>0.05% </td></tr>
    <tr><td>92</td><td><img src="/load_content.php?u=skynet.be" style="width:24px; height:24px;"></td><td>skynet.be</td><td>0.05% </td></tr>
    <tr><td>93</td><td><img src="/load_content.php?u=sympatico.ca" style="width:24px; height:24px;"></td><td>sympatico.ca</td><td>0.05% </td></tr>
    <tr><td>94</td><td><img src="/load_content.php?u=windstream.net" style="width:24px; height:24px;"></td><td>windstream.net</td><td>0.05% </td></tr>
    <tr><td>95</td><td><img src="/load_content.php?u=mac.com" style="width:24px; height:24px;"></td><td>mac.com</td><td>0.05% </td></tr>
    <tr><td>96</td><td><img src="/load_content.php?u=centurytel.net" style="width:24px; height:24px;"></td><td>centurytel.net</td><td>0.05% </td></tr>
    <tr><td>97</td><td><img src="/load_content.php?u=chello.nl" style="width:24px; height:24px;"></td><td>chello.nl</td><td>0.04% </td></tr>
    <tr><td>98</td><td><img src="/load_content.php?u=live.ca" style="width:24px; height:24px;"></td><td>live.ca</td><td>0.04% </td></tr>
    <tr><td>99</td><td><img src="/load_content.php?u=aim.com" style="width:24px; height:24px;"></td><td>aim.com</td><td>0.04% </td></tr>
    <tr><td>100</td><td><img src="/load_content.php?u=bigpond.net.au" style="width:24px; height:24px;"></td><td>bigpond.net.au</td><td>0.04% </td></tr>
"""
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /workspaces/cai-advanced-processing-service/tests/email-analysis.ipynb Cell 9' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://dev-container%2B633a5c55736572735c616c6962696e615c736f757263655c7265706f735c6e65775f6361695f736572766963655c6361692d616476616e6365642d70726f63657373696e672d73657276696365/workspaces/cai-advanced-processing-service/tests/email-analysis.ipynb#ch0000008vscode-remote?line=0'>1</a> txt = pd.read_html('./files/email.html')
#
# File /usr/local/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///usr/local/lib/python3.8/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
# ...
