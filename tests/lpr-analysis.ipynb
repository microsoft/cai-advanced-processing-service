# %%
import pandas as pd

# %% [markdown]
# # analysis benchmark

# %%
df_benchmark = pd.read_csv('./files/lpr_benchmark.csv', header=1, sep=', ' )
df_benchmark.head()
# Out:
# /tmp/ipykernel_15012/3040310035.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_benchmark = pd.read_csv('./files/lpr_benchmark.csv', header=1, sep=', ' )
#                                query  lpr_result         lpr  \
# 0      c l z tower einfach vier neun         NaN  CLZ-HA1649
# 1  r o w p p sieben acht zwei sieben  ROW-PP7827  ROW-PP7627
# 2      r g r t eins sechs sechs null    RG-RT166   RG-RT1660
# 3      video b j fünf eins eins drei         NaN  TDO-BJ5113
# 4      s r w w k neun eins eins null         NaN  FRW-WK9110
#
#                                 cplquery                        luis_entity  \
# 0  das ist c l z tower einfach vier neun      c l z tower einfach vier neun
# 1                     das ist ROW-PP7827  r o w p p sieben acht zwei sieben
# ...

# %%
df_benchmark.groupby('issue').count()
# Out:
#        query  lpr_result  lpr  cplquery  luis_entity
# issue
# luis     189         151  189       189          189
# voice    119          67  119       115          115

# %%
df_benchmark[df_benchmark.issue == 'luis']
# Out:
#                               query lpr_result         lpr  \
# 2     r g r t eins sechs sechs null   RG-RT166   RG-RT1660
# 3     video b j fünf eins eins drei        NaN  TDO-BJ5113
# 4     s r w w k neun eins eins null        NaN  FRW-WK9110
# 5           m m u s zwei vier foils    MM-US24   MM-US2455
# 7     o d x k sieben zwei eins drei    OD-XK72   OD-XK7213
# ..                              ...        ...         ...
# 303   l s n x b zwei neun eins eins   LSN-XB29  LSN-XB2911
# 304    r p q l voice eins eins eins        NaN   RP-QL5111
# 305   d l j z acht sieben drei eins   DL-JZ873   DL-JZ8731
# 306  g n p j k zwei sechs neun zwei        NaN  GNT-JK2692
# 307   t asp p eins sieben eins zwei        NaN  CAS-PP1712
#
#                                    cplquery                luis_entity issue
# 2                      das ist RG-RT166null   r g r t eins sechs sechs  luis
# 3     das ist video b j fünf eins eins drei             video b j fünf  luis
# ...

# %%
df_benchmark[df_benchmark.issue == 'luis']['query'].values
# Out:
# array(['r g r t eins sechs sechs null', 'video b j fünf eins eins drei',
#        's r w w k neun eins eins null', 'm m u s zwei vier foils',
#        'o d x k sieben zwei eins drei', 'a n q w eins fünf vier eins',
#        'b p y e zwei neun drei eins', 'wie o g o acht sechs vier neun',
#        'e g r sechs fünf neun null', 'f f b f y fünf acht null sieben',
#        'g n t h v sieben acht eins sechs', 'g t q foi vier eins zwei',
#        'b h g l neun drinnen eins', 'm y t h sieben acht null zwei',
#        's o n t fünf vier fünf eins', 'h b n n p drei fünf null null',
#        's i v c neun acht vier eins', 'd w o zwei vier sieben eins',
#        'a w b x acht drei eins eins', 'b i w d k sieben null vier drei',
#        'a s l f z sechs sechs drei null', 'h l j c zwei zwei drei eins',
#        's e b d i zwei sechs fünf null', 'w b s d d acht zwei neun eins',
#        'b p s b acht vs acht eins', 'ähm s t k r voice null zwei',
# ...
